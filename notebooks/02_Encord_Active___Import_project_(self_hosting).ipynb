# %% [markdown]
# <div align="center" dir="auto">
# <p dir="auto"><a href="https://colab.research.google.com/drive/1pchKiSZPiu2ENp0pr7iSs3L4JqO6cNAr?usp=sharing" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
# <!--- @encord-active-notebooks {download sanbox project} -->
# <a target="_blank" rel="noopener noreferrer nofollow" href="https://camo.githubusercontent.com/2a088dbe61584d1b213517c05e313c765ca127ce21118626b2d0db0b8f573235/68747470733a2f2f696d672e736869656c64732e696f2f6769746875622f6c6963656e73652f656e636f72642d7465616d2f656e636f72642d616374697665"><img src="https://camo.githubusercontent.com/1a088dbe61584d1b213517c05e313c765ca127ce21118626b2d0db0b8f573235/68747470733a2f2f696d672e736869656c64732e696f2f6769746875622f6c6963656e73652f656e636f72642d7465616d2f656e636f72642d616374697665" alt="Licence" data-canonical-src="https://img.shields.io/github/license/encord-team/encord-active" style="max-width: 100%;"></a>
# <a href="https://www.piwheels.org/project/encord-active/" rel="nofollow"><img src="https://camo.githubusercontent.com/ad0f13bbb94beadb953a46e51cee0db17ade62e4deb8c306e36a7addfa69d18f/68747470733a2f2f696d672e736869656c64732e696f2f707970692f762f656e636f72642d616374697665" alt="PyPi project" data-canonical-src="https://img.shields.io/pypi/v/encord-active" style="max-width: 100%;"></a>
# <a target="_blank" rel="noopener noreferrer nofollow" href="https://camo.githubusercontent.com/890ceffab6602e1a6ecac875e179b3984708f98b0a91293e6c632752d11bad7e/68747470733a2f2f696d672e736869656c64732e696f2f707970692f707976657273696f6e732f656e636f72642d616374697665"><img src="https://camo.githubusercontent.com/890ceffab6602e1a6ecac875e179b3984708f98b0a91293e6c632752d11bad7e/68747470733a2f2f696d672e736869656c64732e696f2f707970692f707976657273696f6e732f656e636f72642d616374697665" alt="PyPi version" data-canonical-src="https://img.shields.io/pypi/pyversions/encord-active" style="max-width: 100%;"></a>
#
# <a href="https://docs.encord.com/active/docs" rel="nofollow"><img src="https://camo.githubusercontent.com/457447b616a4e5aecccd5351fa78d41ce828901e395b935ad2a94d94db75e5d0/68747470733a2f2f696d672e736869656c64732e696f2f62616467652f646f63732d6f6e6c696e652d626c7565" alt="docs" data-canonical-src="https://img.shields.io/badge/docs-online-blue" style="max-width: 100%;"></a>
# <a href="https://discord.gg/TU6yT7Uvx3" rel="nofollow"><img src="https://camo.githubusercontent.com/927173d1e92c30f5e17607e8d270d681c6a665591ba93475b070f4e7f5d2e0e9/68747470733a2f2f736869656c64732e696f2f62616467652f446973636f72642d636861742d626c75653f6c6f676f3d646973636f7264266c6f676f436f6c6f723d7768697465" alt="&quot;Join us on Discord&quot;" data-canonical-src="https://shields.io/badge/Discord-chat-blue?logo=discord&amp;logoColor=white" style="max-width: 100%;"></a>
# <a href="https://github.com/encord-team/encord-notebooks" rel="nofollow"><img src="https://badges.aleen42.com/src/github.svg" alt="&quot;Encord Notebooks;" data-canonical-src="https://badges.aleen42.com/src/github.svg" style="max-width: 100%;"></a>
#
#
# </p>
# <p dir="auto">
# <a href="https://twitter.com/encord_team" rel="nofollow"><img src="https://camo.githubusercontent.com/c7ea37e4d1f0c2e900069152f5990d3bcef4a69c97dede26f08d588958410bd8/68747470733a2f2f696d672e736869656c64732e696f2f747769747465722f666f6c6c6f772f656e636f72645f7465616d3f6c6162656c3d253430656e636f72645f7465616d267374796c653d736f6369616c" alt="Twitter Follow" data-canonical-src="https://img.shields.io/twitter/follow/encord_team?label=%40encord_team&amp;style=social" style="max-width: 100%;"></a></p>
# </div>

# %% [markdown]
# <div align="center">
#   <p>
#     <a align="center" href="" target="_blank">
#       <img
#         width="7232"
#         src="https://storage.googleapis.com/encord-notebooks/encord_active_notebook_banner.png">
#     </a>
#   </p>
# </div>

# %% [markdown]
# # 📓 Encord Active | Getting Started with Encord Projects

# %% [markdown]
# ## 🚀 Overview

# %% [markdown]
# Hi there! 👋 This 📓 notebook shows you how to import existing Encord projects into 🟣 Encord Active.
#
# ⚠️ **Prerequisites:** you should have `encord-active` [installed](https://docs.encord.com/active/docs/installation) and you should have an Encord [account](https://encord.com/).
#
# > If you don't have an Encord project already, you might want to have a look at the [Downloading a sandbox project](./01_Encord_Active_Notebooks___Download_sandbox_project.ipynb) notebook instead.
#
#
# 👟 There are three steps you need to follow to import your first Encord project:
#
# 1. Generate SSH key pairs to connect to the Encord platform.
# 2. Import your Encord Project.
# 3. Start the Encord Active App with your own project.
#
# 📝 _Tip:_ this is equivalent to running the following commands on the command line and following the instructions:
#
# <blockquote>
#
# ```shell
# encord-active import project
# encord-active visualize -t "[project-name]"
# ```
# </blockquote>
#
# > 💡If you want to read more about 🟣 Encord Active checkout our [GitHub](https://github.com/encord-team/encord-active) and [documentation](https://encord-active-docs.web.app/).

# %% [markdown]
# # 🗝️ Generate SSH key pairs to get connected to the Encord platform

# %% [markdown]
# 📜 You will reqire a [public-private key pair](https://docs.encord.com/sdk-and-api/api/getting-started#creating-user-authorization-header) for authentication when using the [Encord SDK](https://python.docs.encord.com/) or [Encord API](https://docs.encord.com/sdk-and-api/api/getting-started).
# You'd need to register the public key with Encord and use your private key as credentials.

# %%
from pathlib import Path

private_key_file = Path.home() / ".ssh" / "encord_key"
public_key_file = private_key_file.with_suffix(".pub")
if not private_key_file.is_file(): 
    print("Generating key file")
    # !ssh-keygen -t ed25519 -f $private_key_file -N '' -q
print(f"public key: {public_key_file.read_text().strip()}")

# !encord-active config set ssh_key_path $private_key_file
# Out:
# public key: ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAIOxbTBwEhzujEqKrzSOo9gUhjRhcphSOXtZotBVqjUYZ stephen@STEPH-Main
# Property `ssh_key_path` has been set.

# %% [markdown]
# ### Steps to register public SSH key to encord

# %% [markdown]
# 1. Open [Encord](https://app.encord.com).
# 2. Go to **User => Settings => Public keys => + New key**.
# 3. Enter
#    **Temporary Colab Key**
#    as **title** and paste your **public key**
#    in the **public key field**.
# 4. Now, you can import your projects.

# %% [markdown]
# ## 👣 Step 2 - 3 are shown below:

# %% [markdown]
# ![Temporary-encord-colab-public-key-step1.png](data:image/png;base64,...)
# ![Temporary-colab-key-step2.png](data:image/png;base64,...)
# ![Temporary-colab-key-step3.png](data:image/png;base64,...)

# %% [markdown]
# # 💻 Choose an 🟣 Encord Project

# %% [markdown]
# **You can utilize the [Python SDK](https://python.docs.encord.com/index.html) to retrieve the list of available projects from Encord that you have access to and review their details to make a selection.**
#
# The steps above are a one-time-only thing. You can repeat the following process for any of your projects without having to deal with ssh keys.
#
# >💡 Learn more about [Encord Projects](https://python.docs.encord.com/tutorials/projects.html?highlight=project#projects).
#
# 📜 Let's start by listing your available projects:

# %%
# !encord-active print encord-projects

# Or by code:
# print(get_projects_json(private_key_file))

# %% [markdown]
# ## ⏬ Importing Encord Project

# %% [markdown]
# Now you are setup to import your projects.
#
#
# From the list, choose the `project-hash` (key-parameter) of the project you want to import and paste it in the command below.
#
# > Replace `<ENTER YOUR PROJECT HASH HERE>` with your project-hash parameter.

# %%
# !encord-active import project --project-hash "<ENTER YOUR PROJECT HASH HERE>"

# %% [markdown]
# ## 🏁 Start the app with your own project

# %% [markdown]
# Encord Active will now have downloaded your data and run the prebuilt metric functions on your data.
# The data will be stored in a subdirectory of your current working directory with the name of the project.
#
# You will be able to see the `[name-of-your-project]` from the prints of the import process.
#
# You can open the app with the following code block. It should open a new tab in your browser. If not, you can click the link printed to open it.

# %%
# !encord-active visualize -t "[name-of-your-project]"

# %% [markdown]
# # Success! Welcome to Encord Active
# ![Encord Active welcome resized.png](data:image/png;base64,...)
#
# ---

# %% [markdown]
# # ✅ Wrap up

# %% [markdown]
# This colab notebook showed you how to import your own project into 🟣Encord Active. If you would like to learn more, check out our [documentation](https://encord-active-docs.web.app/) to find more concrete workflow and guides.
#
# ---
#
# 🟣 Encord Active is an open source tool in its early stage! Check out the project on [GitHub](https://github.com/encord-team/encord-active), leave [a star](https://github.com/encord-team/encord-active) 🌟 if you like it, and leave an issue if you find something is missing.
#
# ---
#
# 👉 Check out our 📖[blog](https://encord.com/blog/webinar-semantic-visual-search-chatgpt-clip/) and 📺[YouTube](https://www.youtube.com/@encord) channel to stay up-to-date with the latest in computer vision, foundation models, active learning, and data-centric AI.
#
#
# Thanks for now!

# %% [markdown]
# # ⏭️ Next: Learn how to use 🟣 Encord Active to explore Torchvision datasets

# %% [markdown]
# What should you check out next? 👀 Learn how to use 🟣 Encord Active to explore Torchvision datasets. The Colab notebook will cover:
#
# * Downloading a dataset through the built-in datasets in the `torchvision.datasets` module.
# * Creating an 🟣 Encord Active project.
# * Inspecting problematic images in the dataset.
# * Exploring more features with 🟣 Encord Active UI.
#
# ### $~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~$ *👇*

# %% [markdown]
# ### *⬅️* [*Previous Notebook*](./01_Encord_Active_Notebooks___Download_sandbox_project.ipynb) $~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~$ [*Next Notebook*](./Encord_Active_Torchvision_Dataset_Exploration.ipynb) *➡️*
